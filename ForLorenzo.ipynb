9050.000000 9100.000000 9150.000000 9200.000000 9250.000000 9300.000000 9350.000000 9400.000000 9450.000000 9500.000000 9550.000000 9600.000000 9650.000000 9700.000000 9750.000000 9800.000000 9850.000000 9900.000000 9950.000000 10000.000000 11000.000000 12000.000000 13000.000000 14000.000000 15000.000000 16000.000000 17000.000000 18000.000000 19000.000000 20000.000000 21000.000000 22000.000000 23000.000000 24000.000000 25000.000000 26000.000000 27000.000000 28000.000000 29000.000000 30000.000000
# NuHepMC.Beam[14].Histogram.ContentIsPerWidth 0
# NuHepMC.Conventions G.C.1 G.C.4 G.C.5 E.C.1 E.C.2 V.C.1 P.C.1 P.C.2 G.C.2 G.C.7
# NuHepMC.Exposure.NEvents 1000
# NuHepMC.FluxAveragedTotalCrossSection 0.0098322333483578
# NuHepMC.ParticleStatusIDs 1 2 3 4 20 21 31 41 99
# NuHepMC.ParticleStatusInfo[1].Description Physical final state particles produced by this simulation
# NuHepMC.ParticleStatusInfo[1].Name UndecayedPhysical
# NuHepMC.ParticleStatusInfo[20].Description The target particle in the hard scatter
# NuHepMC.ParticleStatusInfo[20].Name TargetParticle
# NuHepMC.ParticleStatusInfo[21].Description The nucleon involved in the hard scatter
# NuHepMC.ParticleStatusInfo[21].Name StruckNucleon
# NuHepMC.ParticleStatusInfo[2].Description Particle was decayed by the simulation
# NuHepMC.ParticleStatusInfo[2].Name DecayedPhysical
# NuHepMC.ParticleStatusInfo[31].Description Marks a particle as being Pauli blocked after the hard-scatter was simulated, generally this event should be skipped but included in total cross-section calculations.
# NuHepMC.ParticleStatusInfo[31].Name PauliBlocked
# NuHepMC.ParticleStatusInfo[3].Description Documentation line, not considered a real particle
# NuHepMC.ParticleStatusInfo[3].Name DocumentationLine
# NuHepMC.ParticleStatusInfo[41].Description This particle subsequently underwent FSI and should not be considered part of the final state
# NuHepMC.ParticleStatusInfo[41].Name UnderwentFSI
# NuHepMC.ParticleStatusInfo[4].Description Incoming beam particle
# NuHepMC.ParticleStatusInfo[4].Name IncomingBeam
# NuHepMC.ParticleStatusInfo[99].Description This particle subsequently underwent a secondary interaction in the detector
# NuHepMC.ParticleStatusInfo[99].Name SecondaryInteraction
# NuHepMC.ProcessIDs 276 275 675 488 487 486 485 575 490 489 175 185 479 478 476 475 625 436 435 525 437 125 135 427 426 425 325 225 200 300 400 401 402 110 100 412 500 410 411 600 450 451 452 452 160 150 464 465 550 460 461 462 463 601 250 251
# NuHepMC.ProcessInfo[100].Description neutmode=16
# NuHepMC.ProcessInfo[100].Name CC_COH_nu
# NuHepMC.ProcessInfo[110].Description neutmode=15
# NuHepMC.ProcessInfo[110].Name CC_DIF_nu
# NuHepMC.ProcessInfo[125].Description neutmode=-16
# NuHepMC.ProcessInfo[125].Name CC_COH_nubar
# NuHepMC.ProcessInfo[135].Description neutmode=-15
# NuHepMC.ProcessInfo[135].Name CC_DIF_nubar
# NuHepMC.ProcessInfo[150].Description neutmode=36
# NuHepMC.ProcessInfo[150].Name NC_COH_nu
# NuHepMC.ProcessInfo[160].Description neutmode=35
# NuHepMC.ProcessInfo[160].Name NC_DIF_nu
# NuHepMC.ProcessInfo[175].Description neutmode=-36
# NuHepMC.ProcessInfo[175].Name NC_COH_nubar
# NuHepMC.ProcessInfo[185].Description neutmode=-35
# NuHepMC.ProcessInfo[185].Name NC_DIF_nubar
# NuHepMC.ProcessInfo[200].Description neutmode=1
# NuHepMC.ProcessInfo[200].Name CC_QE_nu
# NuHepMC.ProcessInfo[225].Description neutmode=-1
# NuHepMC.ProcessInfo[225].Name CC_QE_proton_nubar
# NuHepMC.ProcessInfo[250].Description neutmode=51
# NuHepMC.ProcessInfo[250].Name NC_elastic_p_nu
# NuHepMC.ProcessInfo[251].Description neutmode=52
# NuHepMC.ProcessInfo[251].Name NC_elastic_n_nu
# NuHepMC.ProcessInfo[275].Description neutmode=-51
# NuHepMC.ProcessInfo[275].Name NC_elastic_p_nubar
# NuHepMC.ProcessInfo[276].Description neutmode=-52
# NuHepMC.ProcessInfo[276].Name NC_elastic_n_nubar
# NuHepMC.ProcessInfo[300].Description neutmode=2
# NuHepMC.ProcessInfo[300].Name CC_2p2h_nu
# NuHepMC.ProcessInfo[325].Description neutmode=-2
# NuHepMC.ProcessInfo[325].Name CC_2p2h_nubar
# NuHepMC.ProcessInfo[400].Description neutmode=11
# NuHepMC.ProcessInfo[400].Name CC_RES_ppi+_nu
# NuHepMC.ProcessInfo[401].Description neutmode=12
# NuHepMC.ProcessInfo[401].Name CC_RES_ppi0_nu
# NuHepMC.ProcessInfo[402].Description neutmode=13
# NuHepMC.ProcessInfo[402].Name CC_RES_npi+_nu
# NuHepMC.ProcessInfo[410].Description neutmode=22
# NuHepMC.ProcessInfo[410].Name CC_eta_nu
# NuHepMC.ProcessInfo[411].Description neutmode=23
# NuHepMC.ProcessInfo[411].Name CC_kaon_nu
# NuHepMC.ProcessInfo[412].Description neutmode=17
# NuHepMC.ProcessInfo[412].Name CC_1gamma_nu
# NuHepMC.ProcessInfo[425].Description neutmode=-11
# NuHepMC.ProcessInfo[425].Name CC_RES_npi-_nubar
# NuHepMC.ProcessInfo[426].Description neutmode=-12
# NuHepMC.ProcessInfo[426].Name CC_RES_ppi0_nubar
# NuHepMC.ProcessInfo[427].Description neutmode=-13
# NuHepMC.ProcessInfo[427].Name CC_RES_ppi-_nubar
# NuHepMC.ProcessInfo[435].Description neutmode=-22
# NuHepMC.ProcessInfo[435].Name CC_eta_nubar
# NuHepMC.ProcessInfo[436].Description neutmode=-23
# NuHepMC.ProcessInfo[436].Name CC_kaon_nubar
# NuHepMC.ProcessInfo[437].Description neutmode=-17
# NuHepMC.ProcessInfo[437].Name CC_1gamma_nubar
# NuHepMC.ProcessInfo[450].Description neutmode=31
# NuHepMC.ProcessInfo[450].Name NC_RES_npi0_nu
# NuHepMC.ProcessInfo[451].Description neutmode=32
# NuHepMC.ProcessInfo[451].Name NC_RES_ppi0_nu
# NuHepMC.ProcessInfo[452].Description neutmode=34
# NuHepMC.ProcessInfo[452].Name NC_RES_npi+_nu
# NuHepMC.ProcessInfo[460].Description neutmode=42
# NuHepMC.ProcessInfo[460].Name NC_eta_n_nu
# NuHepMC.ProcessInfo[461].Description neutmode=43
# NuHepMC.ProcessInfo[461].Name NC_eta_p_nu
# NuHepMC.ProcessInfo[462].Description neutmode=44
# NuHepMC.ProcessInfo[462].Name NC_kaon_n_nu
# NuHepMC.ProcessInfo[463].Description neutmode=45
# NuHepMC.ProcessInfo[463].Name NC_kaon_p_nu
# NuHepMC.ProcessInfo[464].Description neutmode=38
# NuHepMC.ProcessInfo[464].Name NC_1gamma_n_nu
# NuHepMC.ProcessInfo[465].Description neutmode=39
# NuHepMC.ProcessInfo[465].Name NC_1gamma_p_nu
# NuHepMC.ProcessInfo[475].Description neutmode=-31
# NuHepMC.ProcessInfo[475].Name NC_RES_npi0_nubar
# NuHepMC.ProcessInfo[476].Description neutmode=-32
# NuHepMC.ProcessInfo[476].Name NC_RES_ppi0_nubar
# NuHepMC.ProcessInfo[478].Description neutmode=-33
# NuHepMC.ProcessInfo[478].Name NC_RES_ppi-_nubar
# NuHepMC.ProcessInfo[479].Description neutmode=-34
# NuHepMC.ProcessInfo[479].Name NC_RES_npi+_nubar
# NuHepMC.ProcessInfo[485].Description neutmode=-42
# NuHepMC.ProcessInfo[485].Name NC_eta_n_nubar
# NuHepMC.ProcessInfo[486].Description neutmode=-43
# NuHepMC.ProcessInfo[486].Name NC_eta_p_nubar
# NuHepMC.ProcessInfo[487].Description neutmode=-44
# NuHepMC.ProcessInfo[487].Name NC_kaon_n_nubar
# NuHepMC.ProcessInfo[488].Description neutmode=-45
# NuHepMC.ProcessInfo[488].Name NC_kaon_p_nubar
# NuHepMC.ProcessInfo[489].Description neutmode=-38
# NuHepMC.ProcessInfo[489].Name NC_1gamma_n_nubar
# NuHepMC.ProcessInfo[490].Description neutmode=-39
# NuHepMC.ProcessInfo[490].Name NC_1gamma_p_nubar
# NuHepMC.ProcessInfo[500].Description neutmode=21
# NuHepMC.ProcessInfo[500].Name CC_multi_pi_nu
# NuHepMC.ProcessInfo[525].Description neutmode=-21
# NuHepMC.ProcessInfo[525].Name CC_multi_pi_nubar
# NuHepMC.ProcessInfo[550].Description neutmode=41
# NuHepMC.ProcessInfo[550].Name NC_multi_pi_nu
# NuHepMC.ProcessInfo[575].Description neutmode=-41
# NuHepMC.ProcessInfo[575].Name NC_multi_pi_nubar
# NuHepMC.ProcessInfo[600].Description neutmode=26
# NuHepMC.ProcessInfo[600].Name CC_DIS_nu
# NuHepMC.ProcessInfo[601].Description neutmode=46
# NuHepMC.ProcessInfo[601].Name NC_DIS_nu
# NuHepMC.ProcessInfo[625].Description neutmode=-26
# NuHepMC.ProcessInfo[625].Name CC_DIS_nubar
# NuHepMC.ProcessInfo[675].Description neutmode=-46
# NuHepMC.ProcessInfo[675].Name NC_DIS_nubar
# NuHepMC.Units.CrossSection.TargetScale PerTargetNucleon
# NuHepMC.Units.CrossSection.Unit pb
# NuHepMC.Version.Major 0
# NuHepMC.Version.Minor 9
# NuHepMC.Version.Patch 5
# NuHepMC.VertexStatusIDs 1 2 21
# NuHepMC.VertexStatusInfo[1].Description The neutrino hard-scatter vertex
# NuHepMC.VertexStatusInfo[1].Name PrimaryVertex
# NuHepMC.VertexStatusInfo[21].Description Impulse approximation vertex that represents the separation of the single target nucleon from the target nucleus ground state.
# NuHepMC.VertexStatusInfo[21].Name NucleonSeparationVertex
# NuHepMC.VertexStatusInfo[2].Description A single vertex representing the cascade
# NuHepMC.VertexStatusInfo[2].Name FSIVertex
# ________________________________________________________________________

# %%
ev = hm.GenEvent()

#print the first 4 events using HepMC3 printer
for i in range(3):
    if rdr.failed():
        break
    rdr.read_event(ev)
    
    # check if we got an event or the end of file
    if rdr.failed():
        break
    
    hm.Print.listing(ev)
# Out:
# ________________________________________________________________________
# GenEvent: #0
#  Momentum units: MEV Position units: CM
#  Entries in this event: 3 vertices, 9 particles, 1 weights.
#  Position offset: 0, 0, 0, 0
#                                     GenParticle Legend
#          ID    PDG ID   ( px,       py,       pz,     E )   Stat ProdVtx
# ________________________________________________________________________
# Vtx:     -1 stat:  21 (X,cT): 0
#  I:       11000060120 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00  20     0
#  O:       22009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   3    -1
#           3     2112 -1.90e+02,-2.00e+02,-1.22e+01,+9.79e+02  21    -1
# Vtx:     -2 stat:   1 (X,cT): 0
#  I:       3     2112 -1.90e+02,-2.00e+02,-1.22e+01,+9.79e+02  21    -1
#           4       14 +0.00e+00,+0.00e+00,+4.36e+02,+4.36e+02   4     0
#  O:       5       13 -4.30e+01,-5.93e+01,+3.32e+02,+3.56e+02   3    -2
#           6     2212 -1.47e+02,-1.41e+02,+9.18e+01,+9.64e+02   3    -2
# Vtx:     -3 stat:   2 (X,cT): 0
#  I:       22009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   3    -1
#           5       13 -4.30e+01,-5.93e+01,+3.32e+02,+3.56e+02   3    -2
#           6     2212 -1.47e+02,-1.41e+02,+9.18e+01,+9.64e+02   3    -2
#  O:       72009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   1    -3
#           8       13 -4.30e+01,-5.93e+01,+3.32e+02,+3.56e+02   1    -3
#           9     2212 -1.47e+02,-1.41e+02,+9.18e+01,+9.64e+02   1    -3
# ________________________________________________________________________
# ________________________________________________________________________
# GenEvent: #1
#  Momentum units: MEV Position units: CM
#  Entries in this event: 3 vertices, 9 particles, 1 weights.
#  Position offset: 0, 0, 0, 0
#                                     GenParticle Legend
#          ID    PDG ID   ( px,       py,       pz,     E )   Stat ProdVtx
# ________________________________________________________________________
# Vtx:     -1 stat:  21 (X,cT): 0
#  I:       11000060120 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00  20     0
#  O:       22009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   3    -1
#           3     2112 +4.34e+01,+1.10e+02,-5.27e+01,+9.48e+02  21    -1
# Vtx:     -2 stat:   1 (X,cT): 0
#  I:       3     2112 +4.34e+01,+1.10e+02,-5.27e+01,+9.48e+02  21    -1
#           4       14 +0.00e+00,+0.00e+00,+7.47e+02,+7.47e+02   4     0
#  O:       5       13 -1.50e+02,-3.19e+02,+3.17e+02,+4.85e+02   3    -2
#           6     2212 +1.93e+02,+4.29e+02,+3.78e+02,+1.12e+03   3    -2
# Vtx:     -3 stat:   2 (X,cT): 0
#  I:       22009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   3    -1
#           5       13 -1.50e+02,-3.19e+02,+3.17e+02,+4.85e+02   3    -2
#           6     2212 +1.93e+02,+4.29e+02,+3.78e+02,+1.12e+03   3    -2
#  O:       72009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   1    -3
#           8       13 -1.50e+02,-3.19e+02,+3.17e+02,+4.85e+02   1    -3
#           9     2212 +1.93e+02,+4.29e+02,+3.78e+02,+1.12e+03   1    -3
# ________________________________________________________________________
# ________________________________________________________________________
# GenEvent: #2
#  Momentum units: MEV Position units: CM
#  Entries in this event: 3 vertices, 9 particles, 1 weights.
#  Position offset: 0, 0, 0, 0
#                                     GenParticle Legend
#          ID    PDG ID   ( px,       py,       pz,     E )   Stat ProdVtx
# ________________________________________________________________________
# Vtx:     -1 stat:  21 (X,cT): 0
#  I:       11000060120 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00  20     0
#  O:       22009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   3    -1
#           3     2212 +1.18e+02,+6.90e+01,+5.63e+01,+9.50e+02  21    -1
# Vtx:     -2 stat:   1 (X,cT): 0
#  I:       3     2212 +1.18e+02,+6.90e+01,+5.63e+01,+9.50e+02  21    -1
#           4       14 +0.00e+00,+0.00e+00,+9.38e+02,+9.38e+02   4     0
#  O:       5       14 +3.80e+02,+7.64e+01,-7.98e+01,+3.95e+02   3    -2
#           6     2212 -2.61e+02,-7.42e+00,+1.07e+03,+1.45e+03   3    -2
# Vtx:     -3 stat:   2 (X,cT): 0
#  I:       22009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   3    -1
#           5       14 +3.80e+02,+7.64e+01,-7.98e+01,+3.95e+02   3    -2
#           6     2212 -2.61e+02,-7.42e+00,+1.07e+03,+1.45e+03   3    -2
#  O:       72009900000 +0.00e+00,+0.00e+00,+0.00e+00,+0.00e+00   1    -3
#           8       14 +3.80e+02,+7.64e+01,-7.98e+01,+3.95e+02   1    -3
#           9     2212 -2.61e+02,-7.42e+00,+1.07e+03,+1.45e+03   1    -3
# ________________________________________________________________________

# %%
def get_real_fs_particles(ev):
    # ignore nuclear remnant particles with pid = 2009900000
    return [ p for p in ev.particles() if (p.status() == 1) and (p.pid() != 2009900000) ]

# %%
rdr, run_info = open_hm3file("test1000rome.hepmc3")
ev = hm.GenEvent()

#print the first 4 events using HepMC3 printer
for i in range(3):
    if rdr.failed():
        break
    rdr.read_event(ev)
    print(ev.momentum_unit())

    # check if we got an event or the end of file
    if rdr.failed():
        break
    
    rps = get_real_fs_particles(ev)

    print("\n".join([f"{p.id()}: {p.pid()}, 4mom = [{p.momentum().x()}, {p.momentum().y()}, {p.momentum().z()}, E={p.momentum().e()}]" for p in rps]))
    print("---")
# Out:
# MomentumUnit.MEV
# 8: 13, 4mom = [-43.000919342041016, -59.26547622680664, 332.0616149902344, E=356.0758405794774]
# 9: 2212, 4mom = [-147.3383026123047, -140.6209716796875, 91.77583312988281, E=964.4998347909394]
# ---
# MomentumUnit.MEV
# 8: 13, 4mom = [-149.6416015625, -318.7598571777344, 316.6051330566406, E=485.1833448313953]
# 9: 2212, 4mom = [193.052001953125, 429.2131042480469, 377.87103271484375, E=1115.631559410896]
# ---
# MomentumUnit.MEV
# 8: 14, 4mom = [379.59722900390625, 76.4307632446289, -79.78132629394531, E=395.3489317840906]
# 9: 2212, 4mom = [-261.32763671875, -7.41851282119751, 1073.8209228515625, E=1449.756130206566]
# ---
